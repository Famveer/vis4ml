# %% [markdown]
# # **Visualization of White/Glass-box methods**

# %% [markdown]
# ### **1. Linear Regression**

# %%
import pandas as pd, numpy as np

from sklearn import datasets

# %% [markdown]
# ### **1.1 Diabetes data set** [description](https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset)
#
# Note: All features have been standardized

# %%
data = datasets.load_diabetes()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %% [markdown]
# ### **1.2 Dataset overview**

# %%
X.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %% [markdown]
# ## **1.3 notebookJS**

# %% [markdown]
# ### **Library definition**
#
# 1.   [GitHub](https://github.com/jorgehpo/notebookJS)
#
# ### **Examples of applications**
#
# 1.   [Calibrate](https://ieeexplore.ieee.org/abstract/document/9904444)
# 2.   [PipelineProfiler](https://ieeexplore.ieee.org/abstract/document/9222086)
# 3. [xHiPP](https://ieeexplore.ieee.org/abstract/document/8614350)

# %%
# !pip install notebookjs
from notebookjs import execute_js

# %% [markdown]
# Note: If you are on Google Colab, run the previous cell. Remember using the correct path to load the next files.

# %%
code_js  = open("/content/vis02_LAB.js", "r").read()
code_css = open("vis01.css", "r").read()
d3_path = "https://d3js.org/d3.v7.min.js"

# %%
import random

def python_callback( data ):

  global b
  b = data

  return {'n': random.random(), 'y': 'VisML' }

# %% [markdown]
# ## BOXPLOT
#
# Select one of the features of the diabetes dataset and create a box plot for said feature. It should resemble the one below:
#
# ![image.png](data:image/png;base64,...)

# %%
data = #TO DO

execute_js(library_list=[d3_path, code_js],
           main_function="draw_boxplot", #write this function in the JS file
           css_list=[code_css],
           data_dict={"data": data},
           callbacks={'python_callback': python_callback})

# %% [markdown]
# ## HISTOGRAM
#
# Select one of the features of the diabetes dataset and create a histogram for said feature. It should resemble the one below:
#
# ![image.png](data:image/png;base64,...)

# %%
data = #TO DO

execute_js(library_list=[d3_path, code_js],
           main_function="draw_histogram", #write this function in the JS file
           css_list=[code_css],
           data_dict={"data": data})
